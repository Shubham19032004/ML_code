# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np
import seaborn as sns

# %%
iris=load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target
shuffled_iris_df = iris_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
shuffled_iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  6.1               2.8                4.7               1.2
# 1                  5.7               3.8                1.7               0.3
# 2                  7.7               2.6                6.9               2.3
# 3                  6.0               2.9                4.5               1.5
# 4                  6.8               2.8                4.8               1.4
# ..                 ...               ...                ...               ...
# 145                6.1               2.8                4.0               1.3
# 146                4.9               2.5                4.5               1.7
# 147                5.8               4.0                1.2               0.2
# 148                5.8               2.6                4.0               1.2
# 149                7.1               3.0                5.9               2.1
#
#      target
# 0         1
# 1         0
# 2         2
# 3         1
# 4         1
# ..      ...
# 145       1
# 146       2
# 147       0
# 148       1
# 149       2
#
# [150 rows x 5 columns]

# %%
shuffled_iris_df.to_csv("iris_df",index=False)
